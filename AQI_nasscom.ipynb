# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Nasscom")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Nasscom

# %%
aqi_path = list(os.walk("."))[0][2][1:]
print(aqi_path)
# Out:
# ['MonthlyAQI2020.xlsx', 'MonthlyAQI2022.xlsx', 'MonthlyAQI2021.xlsx', 'MonthlyAQI2019.xlsx', 'Monthly AQI Jan - Dec 2018.xlsx', 'AQI 2016.xlsx', 'AQI 2017 (1).xlsx']

# %%
import pandas as pd
filepath = "/content/drive/MyDrive/Nasscom/"
distrit = ["Karimnagar","Khammam","Kuda, warangal","Mee-Seva, Warangal","Nizamabad","Adilabad"]

# %%
sample = [pd.read_excel(filepath+i) for i in aqi_path]

# %%
sample

# %%
karimnagar = [sample[i].loc[sample[i]['Location']==distrit[0]] for i in range(len(aqi_path))]

# %%
karimnagar

# %%
karimnagar = [karimnagar[i].drop(['Location'],axis=1) for i in range(1,len(aqi_path))]
#karimnagar

# %%
karimnagar = pd.concat(karimnagar)

# %%
karimnagar
# Out:
#    2022-01-01 00:00:00 2022-02-01 00:00:00  2022-03-01 00:00:00  \
# 45                82.0           90.333333            95.666667
# 13                 NaN                 NaN                  NaN
# 12                 NaN                 NaN                  NaN
# 12                 NaN                 NaN                  NaN
# 10                 NaN                 NaN                  NaN
# 10                 NaN                 NaN                  NaN
#
#     2022-04-01 00:00:00 2022-05-01 00:00:00  2022-06-01 00:00:00  \
# 45            69.926215           76.241282                 89.0
# 13                  NaN                 NaN                  NaN
# 12                  NaN                 NaN                  NaN
# 12                  NaN                 NaN                  NaN
# 10                  NaN                 NaN                  NaN
# 10                  NaN                 NaN                  NaN
#
# ...
