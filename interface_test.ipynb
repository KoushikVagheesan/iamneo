# %%
# !pip install gradio

# %%
import gradio as gr


def sentence_builder(Month,District):
    return f"""This is {Month} in {District}"""


demo = gr.Interface(
    sentence_builder,
    [
        gr.Dropdown(["January", "February", "March","April","May","June","July","August","September","October","November","December"]),
        gr.Radio(["Adilabad", "Nizamabad", "Karimnagar","Khammam","Warangal"]),
    ],
    "text",
)

if __name__ == "__main__":
    demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://3a5e9b4c8ccb43e78d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://3a5e9b4c8ccb43e78d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
